# %%
#Common libraries for work with data
import os.path
import pandas as pd
import numpy as np
from sklearn import preprocessing

#Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga datos iniciales (crea el label)
def crear_label(df):
    #Creo la columna Label que contiene el target de si un user hizo(1) o no(0) churn
    df.loc[(df['Label_max_played_dsi'] == 3), 'Label'] = 1
    df.loc[(df['Label_max_played_dsi'] != 3), 'Label'] = 0
    return df

def eliminar_datos_noConfiables(df):
    indexNames = df[(df['Label'] == 1) & (df['install_date'] >= 383)].index
    df.drop(indexNames , inplace=True)
    df = df.reset_index(drop=True)
    return df

def verificar_balance(df,df_aux):
    dif = np.absolute(df['Label'].mean() - df_aux['Label'].mean())
    b=True
    if dif > 0.05:
        b=False
    return b
    
def extraer_muestra(s,df):
    df_aux = df.sample(frac=s, random_state=42)
    if verificar_balance(df,df_aux) == False:
        print('Desbalance')
    else: print('Balanceado')
    return df_aux

def cargar_datos(sample=1):
    #Si existe el archivo de muestra lo levanta
    if (os.path.isfile('../datos/train_sample.csv')) & (sample<1):
        dataset = pd.read_csv('../datos/train_sample.csv')
    #Si existe el archivo total
    elif (os.path.isfile('../datos/train_entero.csv')) & (sample==1):
        dataset = pd.read_csv('../datos/train_entero.csv')
    #Si no existe levanta a todos y crea una muestra
    else:
        dataset = pd.read_csv('../datos/train_1.csv')
        for i in range(2,6):
            df = pd.read_csv('../datos/train_'+str(i)+'.csv')
            dataset = pd.concat([dataset,df],ignore_index=True).drop_duplicates()
        dataset = dataset.reset_index(drop=True)
        
        #No hace falta cambiar los blanks ("") por Nan porque pandas ya lo interpreta como Nan por defecto
        dataset = crear_label(dataset) #Crea el label de churn
        dataset = eliminar_datos_noConfiables(dataset) # Elimina los datos no confiables (383)
        if sample < 1:
            dataset = extraer_muestra(sample,dataset) #Extrae una muestra
            dataset = dataset.reindex(sorted(dataset.columns), axis=1).reset_index(drop=True) #Reinicia los index
        
            #Crea el sample
            dataset.to_csv(r'../datos/train_sample.csv', index = False)
        else:
            dataset.to_csv(r'../datos/train_entero.csv', index = False)
    return dataset

# %%
df = cargar_datos(0.1)

# %%
df.info(verbose = True, null_counts = True)

# Nulls
# ChangeArena_sum_dsi3
# OpenChest_sum_dsi2
# StartBattle_sum_dsi1
# age
# categorical_7
# country
# device_model
# site
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548945 entries, 0 to 548944
# Data columns (total 102 columns):
# BuyCard_sum_dsi0                    548945 non-null int64
# BuyCard_sum_dsi1                    548945 non-null int64
# BuyCard_sum_dsi2                    548945 non-null int64
# BuyCard_sum_dsi3                    548945 non-null int64
# ChangeArena_sum_dsi0                548945 non-null int64
# ChangeArena_sum_dsi1                548945 non-null int64
# ChangeArena_sum_dsi2                548945 non-null int64
# ChangeArena_sum_dsi3                444608 non-null float64
# EnterDeck_sum_dsi0                  548945 non-null int64
# EnterDeck_sum_dsi1                  548945 non-null int64
# EnterDeck_sum_dsi2                  548945 non-null int64
# EnterDeck_sum_dsi3                  548945 non-null int64
# EnterShop_sum_dsi0                  548945 non-null int64
# EnterShop_sum_dsi1                  548945 non-null int64
# EnterShop_sum_dsi2                  548945 non-null int64
# EnterShop_sum_dsi3                  548945 non-null int64
# JoinTournament_sum_dsi0             548945 non-null int64
# JoinTournament_sum_dsi1             548945 non-null int64
# JoinTournament_sum_dsi2             548945 non-null int64
# JoinTournament_sum_dsi3             548945 non-null int64
# Label                               548945 non-null float64
# Label_max_played_dsi                548945 non-null int64
# LoseBattle_sum_dsi0                 548945 non-null int64
# LoseBattle_sum_dsi1                 548945 non-null int64
# LoseBattle_sum_dsi2                 548945 non-null int64
# LoseBattle_sum_dsi3                 548945 non-null int64
# LoseTournamentBattle_sum_dsi0       548945 non-null int64
# LoseTournamentBattle_sum_dsi1       548945 non-null int64
# LoseTournamentBattle_sum_dsi2       548945 non-null int64
# LoseTournamentBattle_sum_dsi3       548945 non-null int64
# OpenChest_sum_dsi0                  548945 non-null int64
# OpenChest_sum_dsi1                  548945 non-null int64
# OpenChest_sum_dsi2                  477367 non-null float64
# OpenChest_sum_dsi3                  548945 non-null int64
# OpenPiggyBank_sum_dsi0              548945 non-null int64
# OpenPiggyBank_sum_dsi1              548945 non-null int64
# OpenPiggyBank_sum_dsi2              548945 non-null int64
# OpenPiggyBank_sum_dsi3              548945 non-null int64
# PiggyBankModifiedPoints_sum_dsi0    548945 non-null int64
# PiggyBankModifiedPoints_sum_dsi1    548945 non-null int64
# PiggyBankModifiedPoints_sum_dsi2    548945 non-null int64
# PiggyBankModifiedPoints_sum_dsi3    548945 non-null int64
# QuitTournament_sum_dsi0             548945 non-null int64
# QuitTournament_sum_dsi1             548945 non-null int64
# QuitTournament_sum_dsi2             548945 non-null int64
# QuitTournament_sum_dsi3             548945 non-null int64
# StartBattle_sum_dsi0                548945 non-null int64
# StartBattle_sum_dsi1                500290 non-null float64
# StartBattle_sum_dsi2                548945 non-null int64
# StartBattle_sum_dsi3                548945 non-null int64
# StartGameplayModeBattle_sum_dsi0    548945 non-null int64
# StartGameplayModeBattle_sum_dsi1    548945 non-null int64
# StartGameplayModeBattle_sum_dsi2    548945 non-null int64
# StartGameplayModeBattle_sum_dsi3    548945 non-null int64
# StartSession_sum_dsi0               548945 non-null int64
# StartSession_sum_dsi1               548945 non-null int64
# StartSession_sum_dsi2               548945 non-null int64
# StartSession_sum_dsi3               548945 non-null int64
# StartTournamentBattle_sum_dsi0      548945 non-null int64
# StartTournamentBattle_sum_dsi1      548945 non-null int64
# StartTournamentBattle_sum_dsi2      548945 non-null int64
# StartTournamentBattle_sum_dsi3      548945 non-null int64
# TutorialFinish                      548945 non-null bool
# TutorialStart                       548945 non-null bool
# TutorialStartPart1                  548945 non-null bool
# TutorialStartPart2                  548945 non-null bool
# TutorialStartPart3                  548945 non-null bool
# TutorialStartPart4                  548945 non-null bool
# TutorialStartPart5                  548945 non-null bool
# TutorialStartPart6                  548945 non-null bool
# UpgradeCard_sum_dsi0                548945 non-null int64
# UpgradeCard_sum_dsi1                548945 non-null int64
# UpgradeCard_sum_dsi2                548945 non-null int64
# UpgradeCard_sum_dsi3                548945 non-null int64
# WinBattle_sum_dsi0                  548945 non-null int64
# WinBattle_sum_dsi1                  548945 non-null int64
# WinBattle_sum_dsi2                  548945 non-null int64
# WinBattle_sum_dsi3                  548945 non-null int64
# WinTournamentBattle_sum_dsi0        548945 non-null int64
# WinTournamentBattle_sum_dsi1        548945 non-null int64
# WinTournamentBattle_sum_dsi2        548945 non-null int64
# WinTournamentBattle_sum_dsi3        548945 non-null int64
# age                                 16404 non-null float64
# categorical_1                       548945 non-null object
# categorical_2                       548945 non-null object
# categorical_3                       548945 non-null object
# categorical_4                       548945 non-null object
# categorical_5                       548945 non-null object
# categorical_6                       548945 non-null object
# categorical_7                       517715 non-null object
# country                             537240 non-null object
# device_model                        548944 non-null object
# hard_negative                       548945 non-null float64
# hard_positive                       548945 non-null float64
# id                                  548945 non-null int64
# install_date                        548945 non-null int64
# platform                            548945 non-null object
# site                                148183 non-null object
# soft_negative                       548945 non-null float64
# soft_positive                       548945 non-null float64
# traffic_type                        548945 non-null int64
# user_id                             548945 non-null object
# dtypes: bool(8), float64(9), int64(73), object(12)
# memory usage: 397.9+ MB
